# %%
# Cell 1: Import Libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
# Cell 2: Load Dataset
d = pd.read_csv(r"C:\Users\joebe\Downloads\user_behavior_dataset.csv")
data.head()  # Display the first few rows of the dataset
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Cell 2: Load Dataset
#       2 d = pd.read_csv(r"C:\Users\joebe\Downloads\user_behavior_dataset.csv")
# ----> 3 data.head()  # Display the first few rows of the dataset
#
# NameError: name 'data' is not defined

# %%
# Cell 3: Data Cleaning
# Remove duplicates
data = data.drop_duplicates()

# Check for missing values
print("Missing values per column:")
print(data.isnull().sum())

# Fill missing numerical values with the mean
numerical_columns = data.select_dtypes(include=['float64', 'int64']).columns
data[numerical_columns] = data[numerical_columns].fillna(data[numerical_columns].mean())

# Fill missing categorical values with the mode
categorical_columns = data.select_dtypes(include=['object']).columns
for col in categorical_columns:
    data[col] = data[col].fillna(data[col].mode()[0])

data.head()  # Display cleaned data
# Out:
# Missing values per column:
# User ID                       0
# Device Model                  0
# Operating System              0
# App Usage Time (min/day)      0
# Screen On Time (hours/day)    0
# Battery Drain (mAh/day)       0
# Number of Apps Installed      0
# Data Usage (MB/day)           0
# Age                           0
# Gender                        0
# User Behavior Class           0
# dtype: int64
#    User ID    Device Model Operating System  App Usage Time (min/day)  \
# 0        1  Google Pixel 5          Android                       393
# 1        2       OnePlus 9          Android                       268
# 2        3    Xiaomi Mi 11          Android                       154
# 3        4  Google Pixel 5          Android                       239
# 4        5       iPhone 12              iOS                       187
#
#    Screen On Time (hours/day)  Battery Drain (mAh/day)  \
# 0                         6.4                     1872
# ...

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Load your dataset (example)
data = pd.read_csv(r"C:\Users\joebe\Downloads\user_behavior_dataset.csv") # Replace with your actual file path

# Check the column names
print(data.columns)  # This will help you identify the exact names

# Now update the features and target based on your column names
# Assuming 'sales' is the target column, and these are your feature columns
features = ['User ID', 'Device Model', 'Operating System']  # Replace with actual feature columns
target = 'sales'  # Replace with your actual target column name

# Ensure 'sales' exists in the columns (check for exact match)
if target not in data.columns:
    print(f"Target column '{target}' does not exist in the dataset.")
else:
    # Select the features and target columns
    X = data[features]  # Features data
    y = data[target]  # Target data

    # Check if X and y are extracted correctly
    print(X.head())
    print(y.head())

    # Standardize the features
    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X)

    # Now you can proceed with your model (e.g., training)
    # For example, here you can use a model like LinearRegression, RandomForest, etc.
    # from sklearn.linear_model import LinearRegression
    # model = LinearRegression()
    # model.fit(X_scaled, y)

    # For now, just confirm that X is scaled properly
    print("Scaled features (first 5 rows):")
    print(X_scaled[:5])  # Print first 5 rows of scaled features
# Out:
# Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='object')
# Target column 'sales' does not exist in the dataset.

# %%
# Import necessary libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer

# Load your dataset (example path)
data = pd.read_csv(r"C:\Users\joebe\Downloads\user_behavior_dataset.csv")

# Check column names in the dataset
print("Columns in dataset:", data.columns)

# Define feature and target columns
features = ['User ID', 'Device Model', 'Operating System']  # Adjust feature columns if needed
target = 'User Behavior Class'  # Set the correct target column name

# Check if the target column exists
if target not in data.columns:
    raise ValueError(f"Target column '{target}' not found in dataset. Available columns are: {data.columns.tolist()}")

# Check if all feature columns exist
missing_features = [feature for feature in features if feature not in data.columns]
if missing_features:
    raise ValueError(f"Feature columns {missing_features} not found in dataset. Available columns are: {data.columns.tolist()}")

# Select the feature and target columns
X = data[features]
y = data[target]

# Define categorical and numerical columns
categorical_features = ['Device Model', 'Operating System']
numerical_features = ['User ID']  # Add other numerical columns if necessary

# Create a column transformer to handle the preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),  # Standardize numerical features
        ('cat', OneHotEncoder(), categorical_features)   # One-hot encode categorical features
    ])

# Create a pipeline with the preprocessor and a placeholder for modeling
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

# Apply the transformations to the data
X_transformed = pipeline.fit_transform(X)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2, random_state=42)

# Print the shapes of the resulting splits to confirm
print("Training set shape:", X_train.shape, y_train.shape)
print("Test set shape:", X_test.shape, y_test.shape)
# Out:
# Columns in dataset: Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='object')
# Training set shape: (560, 8) (560,)
# Test set shape: (140, 8) (140,)

# %%
# Import necessary libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression

# Load your dataset (example path)
data = pd.read_csv(r"C:\Users\joebe\Downloads\user_behavior_dataset.csv")

# Check column names in the dataset
print("Columns in dataset:", data.columns)

# Define feature and target columns
features = ['User ID', 'Device Model', 'Operating System']  # Adjust feature columns if needed
target = 'User Behavior Class'  # Set the correct target column name

# Check if the target column exists
if target not in data.columns:
    raise ValueError(f"Target column '{target}' not found in dataset. Available columns are: {data.columns.tolist()}")

# Check if all feature columns exist
missing_features = [feature for feature in features if feature not in data.columns]
if missing_features:
    raise ValueError(f"Feature columns {missing_features} not found in dataset. Available columns are: {data.columns.tolist()}")

# Select the feature and target columns
X = data[features]
y = data[target]

# Define categorical and numerical columns
categorical_features = ['Device Model', 'Operating System']
numerical_features = ['User ID']  # Add other numerical columns if necessary

# Create a column transformer to handle the preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),  # Standardize numerical features
        ('cat', OneHotEncoder(), categorical_features)   # One-hot encode categorical features
    ])

# Create a pipeline with the preprocessor
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

# Apply the transformations to the data
X_transformed = pipeline.fit_transform(X)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2, random_state=42)

# Print the shapes of the resulting splits to confirm
print("Training set shape:", X_train.shape, y_train.shape)
print("Test set shape:", X_test.shape, y_test.shape)

# Now, proceed with model training
model = LinearRegression()
model.fit(X_train, y_train)

# Model training is complete. You can make predictions with the model:
y_pred = model.predict(X_test)

# Print predictions (for example)
print("Predictions:", y_pred)
# Out:
# Columns in dataset: Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='object')
# Training set shape: (560, 8) (560,)
# Test set shape: (140, 8) (140,)
# Predictions: [2.96734353 2.94771647 2.99938514 3.0461967  2.98248522 2.95685464
#  3.19320907 2.98870087 3.01803207 3.16951193 2.91411316 2.93665318
#  3.03765019 2.98288264 2.88168421 2.88964738 2.913733   2.97782463
#  3.11687321 3.14173578 2.92810729 3.17300823 2.88984224 2.94403425
#  2.98967206 3.1743679  2.90751735 3.03434699 3.02813249 2.95471801
#  2.97219951 2.97277442 2.97161679 2.97919148 3.00967866 2.96092471
#  2.89178401 2.98248636 3.13823948 3.01919636 3.04211768 3.03085069
#  2.95102685 2.88809347 2.91858065 2.96053738 2.86847597 2.97646382
# ...

# %%
# Import necessary libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# Load your dataset (example path)
data = pd.read_csv(r"C:\Users\joebe\Downloads\user_behavior_dataset.csv")

# Check column names in the dataset
print("Columns in dataset:", data.columns)

# Define feature and target columns
features = ['User ID', 'Device Model', 'Operating System']  # Adjust feature columns if needed
target = 'User Behavior Class'  # Set the correct target column name

# Check if the target column exists
if target not in data.columns:
    raise ValueError(f"Target column '{target}' not found in dataset. Available columns are: {data.columns.tolist()}")

# Check if all feature columns exist
missing_features = [feature for feature in features if feature not in data.columns]
if missing_features:
    raise ValueError(f"Feature columns {missing_features} not found in dataset. Available columns are: {data.columns.tolist()}")

# Select the feature and target columns
X = data[features]
y = data[target]

# Define categorical and numerical columns
categorical_features = ['Device Model', 'Operating System']
numerical_features = ['User ID']  # Add other numerical columns if necessary

# Create a column transformer to handle the preprocessing
preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_features),  # Standardize numerical features
        ('cat', OneHotEncoder(), categorical_features)   # One-hot encode categorical features
    ])

# Create a pipeline with the preprocessor
pipeline = Pipeline(steps=[('preprocessor', preprocessor)])

# Apply the transformations to the data
X_transformed = pipeline.fit_transform(X)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_transformed, y, test_size=0.2, random_state=42)

# Print the shapes of the resulting splits to confirm
print("Training set shape:", X_train.shape, y_train.shape)
print("Test set shape:", X_test.shape, y_test.shape)

# Now, proceed with model training
model = LinearRegression()
model.fit(X_train, y_train)

# Prediction and Evaluation
y_pred = model.predict(X_test)

# Calculate Mean Squared Error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Display first 5 predictions
print("Predicted values:", y_pred[:5])
# Out:
# Columns in dataset: Index(['User ID', 'Device Model', 'Operating System',
#        'App Usage Time (min/day)', 'Screen On Time (hours/day)',
#        'Battery Drain (mAh/day)', 'Number of Apps Installed',
#        'Data Usage (MB/day)', 'Age', 'Gender', 'User Behavior Class'],
#       dtype='object')
# Training set shape: (560, 8) (560,)
# Test set shape: (140, 8) (140,)
# Mean Squared Error: 1.8606566870216283
# Predicted values: [2.96734353 2.94771647 2.99938514 3.0461967  2.98248522]
